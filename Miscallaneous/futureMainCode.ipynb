# %%
class SAMergingAlgo:
    def __init__(self, studentModel, teacherModels, dataset):
        self.mergedModel = studentModel
        self.teachers = teacherModels
        self.dataset = dataset
        pass
